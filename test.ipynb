# %%
import re

# %%
str =''' 
{
    "personal_id": "P005",
    "per_id": "per_id_1753682676639466",
    "full_name": "Tạ Chiêu Trung", 
    "birth_year_or_age": null,
    "gender": "Male",
    "nationality": "Việt Nam", 
    "occupation_or_position": null,
    "education_or_qualifications": null,
    "previous_roles": [],
    "organization": "Ngân hàng SCB",
    "hometown_or_residence": null,
    "aliases": [],
    "violations": [
        {
            "customer_role": "Đồng phạm",
            "risk_severity": "Nghiêm trọng", 
            "laws_or_regulations_violated": [],
            "personal_relationships": "Thực hiện ý chí của Trương Mỹ Lan",
            "appeal_status": "Đang kháng cáo",
            "violation_type": "Tham nhũng/Chiếm đoạt tài sản",
            "jurisdiction_of_violation": "TP.HCM, Việt Nam",
            "mitigation_actions": null,
            "financial_impact_of_violation": "Không rõ",
            "date_of_violation": null,
            "legal_status": "Đang trong quá trình điều tra"
        },
        {
            "customer_role": "Đồng phạm",
            "risk_severity": "Nghiêm trọng",
            "laws_or_regulations_violated": [],
            "personal_relationships": "Thực hiện ý chí của Trương Mỹ Lan", 
            "appeal_status": "Đang kháng cáo",
            "violation_type": "Tham nhũng",
            "jurisdiction_of_violation": "TP.HCM, Việt Nam",
            "mitigation_actions": null,
            "financial_impact_of_violation": "Không rõ",
            "date_of_violation": null,
            "legal_status": "Đã kết án"
        }
    ]
}
'''



pattern = r'(\{.*?\})'
match = re.search(pattern, str, re.DOTALL)

# %%
cd ..
# Out:
# d:\
# C:\Users\hoivd\AppData\Roaming\Python\Python312\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from utils import Utils
print(Utils.json_to_str(match[0]))
# Out:
# "{\n    \"personal_id\": \"P005\",\n    \"per_id\": \"per_id_1753682676639466\",\n    \"full_name\": \"Tạ Chiêu Trung\", \n    \"birth_year_or_age\": null,\n    \"gender\": \"Male\",\n    \"nationality\": \"Việt Nam\", \n    \"occupation_or_position\": null,\n    \"education_or_qualifications\": null,\n    \"previous_roles\": [],\n    \"organization\": \"Ngân hàng SCB\",\n    \"hometown_or_residence\": null,\n    \"aliases\": [],\n    \"violations\": [\n        {\n            \"customer_role\": \"Đồng phạm\",\n            \"risk_severity\": \"Nghiêm trọng\", \n            \"laws_or_regulations_violated\": [],\n            \"personal_relationships\": \"Thực hiện ý chí của Trương Mỹ Lan\",\n            \"appeal_status\": \"Đang kháng cáo\",\n            \"violation_type\": \"Tham nhũng/Chiếm đoạt tài sản\",\n            \"jurisdiction_of_violation\": \"TP.HCM, Việt Nam\",\n            \"mitigation_actions\": null,\n            \"financial_impact_of_violation\": \"Không rõ\",\n         
# ...
